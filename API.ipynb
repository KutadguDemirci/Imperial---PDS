# %% [markdown]
# ## Terminology
# ### Web API
# Web application programming interfaces (APIs) are a way of interacting with external computer systems via the internet. These APIs essentially enable the calling of functions on other computers that can return data or perform operations on the external computer system (such as registering a user, making a move in a game of chess etc.).
#
# ### HTTP
# HTTP is a protocol for the most common type of API on the internet. As a protocol, all HTTP does is establish a convention for sending messages between computers on the internet. There are four main types of message:
#
# - **GET**: GET-ing a URL returns data/a webpage. When you load a website by typing a URL, your browser sends a GET request in the background to the URL of the web application and the server decides what to return.
# - **POST**: POST-ing to a URL sends new data to the web application.
# - **PUT**: PUT-ing to a URL updates the state associated with the web application.
# - **DELETE**: DELETE-ing to a URL removes data associated with the web application.
#
# Since HTTP is a protocol, it is ultimately up to the developers of the web application what actually happens when you send an HTTP request.
#
# ### Endpoint
# A URL that a web application uses to receive API requests is called an 'endpoint'.
#
# ### Root URL
# A dedicated URL to handle all requests for a specific web application is called 'root' URL. As a developer we can specify more granular endpoints by appending to the path of the 'root' URL.
#
# For example, in `https://api.tfl.gov.uk/AirQuality`, `https://api.tfl.gov.uk` is the root URL and we request the `AirQuality` endpoint.
#
# ### JSON
# JSON is a standard text format for encoding data to be transmitted between computers in requests and responses to APIs.

# %% [markdown]
# ## Some API examples in Python
#
# `requests` is a common and simple library for working with HTTP APIs. Check out the documentation https://requests.readthedocs.io/en/latest/ for specific details. Below we send a GET request to www.google.com, the same way a browser would do when access the URL.

# %%
# uncomment the following line to install the library into your Jupyter kernel if you have not done so already
#! pip install requests

import requests

res = requests.get("https://www.google.com")
res
# Out:
# <Response [200]>

# %% [markdown]
# The response by the server contains the data and meta-data associated with the request. Here we explore `status_code` and `text`. `status_code` encodes if the server successfully interpreted and handled our request. See https://developer.mozilla.org/en-US/docs/Web/HTTP/Status for details on the status codes returned.

# %%
res.status_code
# Out:
# 200

# %% [markdown]
# The data in text form can be accessed by `text`.

# %%
res.text
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en-GB"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="Ugg4WtTh3UPzMoJL-3lvrg">(function(){var _g={kEI:\'uQ0RZ8ORLZqB9u8Pus_1yQ0\',kEXPI:\'0,1303875,2396450,114,945,448529,90132,2872,2891,73050,16105,18161,162437,23024,6700,96770,29549,8155,23351,22435,9779,62658,31491,44717,15816,1804,7734,27535,2413,9400,1632,29279,21780,5303,5212676,996,26,113,8832397,1222,11,1,42,7439818,20539939,16673,43886,3,1603,3,2124363,23029351,8163,4636,16436,95587,11081,15164,8181,17876,45673,6968,581,6756,155,1,1,2482,13504,7736,9138,4600,328,3216,5,1238,1766,1117,1830,17654,4863,8160,687,7850,22,2761,180,13256,5785,970,371,8822,4829,57,360,1852,2,9,11640,1768,2381,2462,3296,7767,348,1557,6853,1539,4176,797,8677,1,8192,7114,3066,111,376,4144,5390,1458,5,29,1514,251,597,1801,914,78,3,2,8,2,308,2095,2455,129,3147,2816,1080,2,2,3,273,2,1176,41,1928,2,2,3,1351,2,2255,486,2487,3366,1159,198,400,1,1753,884,614,10,1097,1181,1587,980,1,32,1346,1041,320,301,258,3,1,206,986,397,49,1,89,802,955,269,1036,2,2,5,450,4,1,6,3780,1531,21,130,162,1434,2061,919,2270,404,288,718,140,500,3,281,1890,3,1194,217,87,25,1222,154,530,40,47,339,462,326,1,2,4,2,961,281,192,23,872,3,7,149,27,479,143,442,448,4,4,24,260,30,2,6,2,700,207,62,69,862,1865,708,404,220,172,302,118,120,36,389,68,73,151,571,5,120,261,1522,2,806,2,241,416,3,178,618,3,1349,261,122,11,49,87,1056,2,137,41,553,173,843,110,43,4,750,1,8,1,1,4,1,4,60,2086,140,3,1060,2,2190,2,29,1177,1492,21419616,3,11622,4,4275,3,16997,18,218,1786,1480,866,363,636,71,598\',kBL:\'hfY1\',kOPI:89978449};(function(){var a;((a=window.google)==null?0:a.stvsc)?google.kEI=_g.kEI:window.google=_g;}).call(this);})();(function(){google.sn=\'webhp\';google.kHL=\'en-GB\';})();(function(){\nvar h=this||self;function l(){return window.google!==void 0&&window.google.kOPI!==void 0&&window.google.kOPI!==0?window.google.kOPI:null};var m,n=[];function p(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||m}function q(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b}function r(a){/^http:/i.test(a)&&window.location.protocol==="https:"&&(google.ml&&google.ml(Error("a"),!1,{src:a,glmm:1}),a="");return a}\nfunction t(a,b,c,d,k){var e="";b.search("&ei=")===-1&&(e="&ei="+p(d),b.search("&lei=")===-1&&(d=q(d))&&(e+="&lei="+d));d="";var g=b.search("&cshid=")===-1&&a!=="slh",f=[];f.push(["zx",Date.now().toString()]);h._cshid&&g&&f.push(["cshid",h._cshid]);c=c();c!=null&&f.push(["opi",c.toString()]);for(c=0;c<f.length;c++){if(c===0||c>0)d+="&";d+=f[c][0]+"="+f[c][1]}return"/"+(k||"gen_204")+"?atyp=i&ct="+String(a)+"&cad="+(b+e+d)};m=google.kEI;google.getEI=p;google.getLEI=q;google.ml=function(){return null};google.log=function(a,b,c,d,k,e){e=e===void 0?l:e;c||(c=t(a,b,e,d,k));if(c=r(c)){a=new Image;var g=n.length;n[g]=a;a.onerror=a.onload=a.onabort=function(){delete n[g]};a.src=c}};google.logUrl=function(a,b){b=b===void 0?l:b;return t("",a,b)};}).call(this);(function(){google.y={};google.sy=[];var d;(d=google).x||(d.x=function(a,b){if(a)var c=a.id;else{do c=Math.random();while(google.y[c])}google.y[c]=[a,b];return!1});var e;(e=google).sx||(e.sx=function(a){google.sy.push(a)});google.lm=[];var f;(f=google).plm||(f.plm=function(a){google.lm.push.apply(google.lm,a)});google.lq=[];var g;(g=google).load||(g.load=function(a,b,c){google.lq.push([[a],b,c])});var h;(h=google).loadAll||(h.loadAll=function(a,b){google.lq.push([a,b])});google.bx=!1;var k;(k=google).lx||(k.lx=function(){});var l=[],m;(m=google).fce||(m.fce=function(a,b,c,n){l.push([a,b,c,n])});google.qce=l;}).call(this);google.f={};(function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a=c==="1"||c==="q"&&!a.elemen ...

# %% [markdown]
# This works as long as the encoding (check `res.encoding`) is correct. Otherwise, we can set the encoding and try again, or look at the data in binary form with `res.content`, which will be a string starting with `b` to indicate that this is a byte string, and which may indicate the encoding. Here it's essentially the same string as above.

# %%
res.content
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en-GB"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="Ugg4WtTh3UPzMoJL-3lvrg">(function(){var _g={kEI:\'uQ0RZ8ORLZqB9u8Pus_1yQ0\',kEXPI:\'0,1303875,2396450,114,945,448529,90132,2872,2891,73050,16105,18161,162437,23024,6700,96770,29549,8155,23351,22435,9779,62658,31491,44717,15816,1804,7734,27535,2413,9400,1632,29279,21780,5303,5212676,996,26,113,8832397,1222,11,1,42,7439818,20539939,16673,43886,3,1603,3,2124363,23029351,8163,4636,16436,95587,11081,15164,8181,17876,45673,6968,581,6756,155,1,1,2482,13504,7736,9138,4600,328,3216,5,1238,1766,1117,1830,17654,4863,8160,687,7850,22,2761,180,13256,5785,970,371,8822,4829,57,360,1852,2,9,11640,1768,2381,2462,3296,7767,348,1557,6853,1539,4176,797,8677,1,8192,7114,3066,111,376,4144,5390,1458,5,29,1514,251,597,1801,914,78,3,2,8,2,308,2095,2455,129,3147,2816,1080,2,2,3,273,2,1176,41,1928,2,2,3,1351,2,2255,486,2487,3366,1159,198,400,1,1753,884,614,10,1097,1181,1587,980,1,32,1346,1041,320,301,258,3,1,206,986,397,49,1,89,802,955,269,1036,2,2,5,450,4,1,6,3780,1531,21,130,162,1434,2061,919,2270,404,288,718,140,500,3,281,1890,3,1194,217,87,25,1222,154,530,40,47,339,462,326,1,2,4,2,961,281,192,23,872,3,7,149,27,479,143,442,448,4,4,24,260,30,2,6,2,700,207,62,69,862,1865,708,404,220,172,302,118,120,36,389,68,73,151,571,5,120,261,1522,2,806,2,241,416,3,178,618,3,1349,261,122,11,49,87,1056,2,137,41,553,173,843,110,43,4,750,1,8,1,1,4,1,4,60,2086,140,3,1060,2,2190,2,29,1177,1492,21419616,3,11622,4,4275,3,16997,18,218,1786,1480,866,363,636,71,598\',kBL:\'hfY1\',kOPI:89978449};(function(){var a;((a=window.google)==null?0:a.stvsc)?google.kEI=_g.kEI:window.google=_g;}).call(this);})();(function(){google.sn=\'webhp\';google.kHL=\'en-GB\';})();(function(){\nvar h=this||self;function l(){return window.google!==void 0&&window.google.kOPI!==void 0&&window.google.kOPI!==0?window.google.kOPI:null};var m,n=[];function p(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||m}function q(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b}function r(a){/^http:/i.test(a)&&window.location.protocol==="https:"&&(google.ml&&google.ml(Error("a"),!1,{src:a,glmm:1}),a="");return a}\nfunction t(a,b,c,d,k){var e="";b.search("&ei=")===-1&&(e="&ei="+p(d),b.search("&lei=")===-1&&(d=q(d))&&(e+="&lei="+d));d="";var g=b.search("&cshid=")===-1&&a!=="slh",f=[];f.push(["zx",Date.now().toString()]);h._cshid&&g&&f.push(["cshid",h._cshid]);c=c();c!=null&&f.push(["opi",c.toString()]);for(c=0;c<f.length;c++){if(c===0||c>0)d+="&";d+=f[c][0]+"="+f[c][1]}return"/"+(k||"gen_204")+"?atyp=i&ct="+String(a)+"&cad="+(b+e+d)};m=google.kEI;google.getEI=p;google.getLEI=q;google.ml=function(){return null};google.log=function(a,b,c,d,k,e){e=e===void 0?l:e;c||(c=t(a,b,e,d,k));if(c=r(c)){a=new Image;var g=n.length;n[g]=a;a.onerror=a.onload=a.onabort=function(){delete n[g]};a.src=c}};google.logUrl=function(a,b){b=b===void 0?l:b;return t("",a,b)};}).call(this);(function(){google.y={};google.sy=[];var d;(d=google).x||(d.x=function(a,b){if(a)var c=a.id;else{do c=Math.random();while(google.y[c])}google.y[c]=[a,b];return!1});var e;(e=google).sx||(e.sx=function(a){google.sy.push(a)});google.lm=[];var f;(f=google).plm||(f.plm=function(a){google.lm.push.apply(google.lm,a)});google.lq=[];var g;(g=google).load||(g.load=function(a,b,c){google.lq.push([[a],b,c])});var h;(h=google).loadAll||(h.loadAll=function(a,b){google.lq.push([a,b])});google.bx=!1;var k;(k=google).lx||(k.lx=function(){});var l=[],m;(m=google).fce||(m.fce=function(a,b,c,n){l.push([a,b,c,n])});google.qce=l;}).call(this);google.f={};(function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a=c==="1"||c==="q"&&!a.element ...

# %% [markdown]
# For those among you with some HTML experience will notice that `res.text` is just some HTML describing a webpage. Typically HTML is designed to format and mark up documents to be easily read by humans. As data scientists, instead we wish to process the returned data using computers, so the HTML mark up is unnecessary. Therefore, web applications typically offer API endpoints returning JSON data.
#
# As an example, Transport for London (TfL) offers such an endpoint for information on air quality.

# %%
res = requests.get("https://api.tfl.gov.uk/AirQuality")
res.text
# Out:
# '{"$id":"1","$type":"Tfl.Api.Presentation.Entities.LondonAirForecast, Tfl.Api.Presentation.Entities","updatePeriod":"hourly","updateFrequency":"1","forecastURL":"http://londonair.org.uk/forecast","disclaimerText":"This forecast is intended to provide information on expected pollution levels in areas of significant public exposure. It may not apply in very specific locations close to unusually strong or short-lived local sources of pollution.","currentForecast":[{"$id":"2","$type":"Tfl.Api.Presentation.Entities.CurrentForecast, Tfl.Api.Presentation.Entities","forecastType":"Current","forecastID":"46707","forecastBand":"Low","forecastSummary":"Low air pollution forecast valid from Thursday 17 October to end of Friday 18 October GMT","nO2Band":"Low","o3Band":"Low","pM10Band":"Low","pM25Band":"Low","sO2Band":"Low","forecastText":"Rain will clear overnight for Thursday morning, still with odd shower through the day. Foggy start on Friday, then mainly dry and sunny for the rest of the day. Cloud will develop in the evening. &lt;br/&gt;Good dispersion to local emissions.&lt;br/&gt;&lt;br/&gt;Air pollution is expected to remain &#39;Low&#39; for the following pollutants:&lt;br/&gt;&lt;br/&gt;Nitrogen Dioxide&lt;br/&gt;Ozone&lt;br/&gt;Sulphur Dioxide&lt;br/&gt;PM10 Particulates&lt;br/&gt;PM2.5 Particulates &lt;br/&gt;&lt;br/&gt;"},{"$id":"3","$type":"Tfl.Api.Presentation.Entities.CurrentForecast, Tfl.Api.Presentation.Entities","forecastType":"Future","forecastID":"46719","forecastBand":"Low","forecastSummary":"Low air pollution forecast valid from Friday 18 October to end of Saturday 19 October GMT","nO2Band":"Low","o3Band":"Low","pM10Band":"Low","pM25Band":"Low","sO2Band":"Low","forecastText":"Foggy start on Friday, then mainly dry and sunny for the rest of the day. Cloud and rail arrive in the evening. Cloud and rain will clear on Saturday morning, remaining dry with sunny intervals in the afternoon.  &lt;br/&gt;Good dispersion to local emissions with the Atlantic air flow.&lt;br/&gt;&lt;br/&gt;Air pollution is expected to remain &#39;Low&#39; for the following pollutants:&lt;br/&gt;&lt;br/&gt;Nitrogen Dioxide&lt;br/&gt;Ozone&lt;br/&gt;Sulphur Dioxide&lt;br/&gt;PM10 Particulates&lt;br/&gt;PM2.5 Particulates &lt;br/&gt;&lt;br/&gt;"}]}'

# %% [markdown]
# As we have seen in the previous week, JSON can be translated to Python objects such a dictionaries and lists.

# %%
res_dict = res.json()
print(res_dict)
print(type(res_dict))
# Out:
# {'$id': '1', '$type': 'Tfl.Api.Presentation.Entities.LondonAirForecast, Tfl.Api.Presentation.Entities', 'updatePeriod': 'hourly', 'updateFrequency': '1', 'forecastURL': 'http://londonair.org.uk/forecast', 'disclaimerText': 'This forecast is intended to provide information on expected pollution levels in areas of significant public exposure. It may not apply in very specific locations close to unusually strong or short-lived local sources of pollution.', 'currentForecast': [{'$id': '2', '$type': 'Tfl.Api.Presentation.Entities.CurrentForecast, Tfl.Api.Presentation.Entities', 'forecastType': 'Current', 'forecastID': '46707', 'forecastBand': 'Low', 'forecastSummary': 'Low air pollution forecast valid from Thursday 17 October to end of Friday 18 October GMT', 'nO2Band': 'Low', 'o3Band': 'Low', 'pM10Band': 'Low', 'pM25Band': 'Low', 'sO2Band': 'Low', 'forecastText': 'Rain will clear overnight for Thursday morning, still with odd shower through the day. Foggy start on Friday, then mainly dry and sunny for the rest of the day. Cloud will develop in the evening. &lt;br/&gt;Good dispersion to local emissions.&lt;br/&gt;&lt;br/&gt;Air pollution is expected to remain &#39;Low&#39; for the following pollutants:&lt;br/&gt;&lt;br/&gt;Nitrogen Dioxide&lt;br/&gt;Ozone&lt;br/&gt;Sulphur Dioxide&lt;br/&gt;PM10 Particulates&lt;br/&gt;PM2.5 Particulates &lt;br/&gt;&lt;br/&gt;'}, {'$id': '3', '$type': 'Tfl.Api.Presentation.Entities.CurrentForecast, Tfl.Api.Presentation.Entities', 'forecastType': 'Future', 'forecastID': '46719', 'forecastBand': 'Low', 'forecastSummary': 'Low air pollution forecast valid from Friday 18 October to end of Saturday 19 October GMT', 'nO2Band': 'Low', 'o3Band': 'Low', 'pM10Band': 'Low', 'pM25Band': 'Low', 'sO2Band': 'Low', 'forecastText': 'Foggy start on Friday, then mainly dry and sunny for the rest of the day. Cloud and rail arrive in the evening. Cloud and rain will clear on Saturday morning, remaining dry with sunny intervals in the afternoon.  &lt;br/&gt;Good dispersion to local emissions with the Atlantic air flow.&lt;br/&gt;&lt;br/&gt;Air pollution is expected to remain &#39;Low&#39; for the following pollutants:&lt;br/&gt;&lt;br/&gt;Nitrogen Dioxide&lt;br/&gt;Ozone&lt;br/&gt;Sulphur Dioxide&lt;br/&gt;PM10 Particulates&lt;br/&gt;PM2.5 Particulates &lt;br/&gt;&lt;br/&gt;'}]}
# <class 'dict'>

# %% [markdown]
# It is possible to use specific parameters in a request to filter the data. There are two common conventions to supply these arguments:
#
#     1. Via the URL path. In the Tfl example, the second part of the URL path can be used to specify which year of accident statistics to retrieve
# https://api.tfl.gov.uk/swagger/ui/index.html?url=/swagger/docs/v1#!/AccidentStats/AccidentStats_Get

# %%
res = requests.get("https://api.tfl.gov.uk/AccidentStats/2019")
res.json()
# Out:
# [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 345979,
#   'lat': 51.570865,
#   'lon': -0.231959,
#   'location': 'On Edgware Road Near The Junction With north Circular Road',
#   'date': '2019-01-04T21:22:00Z',
#   'severity': 'Slight',
#   'borough': 'Barnet',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 20,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'PoweredTwoWheeler',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Motorcycle_500cc_Plus'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 345980,
#   'lat': 51.603859,
#   'lon': -0.18724,
#   'location': 'On Willow Way Near The Junction With Long Lane',
#   'date': '2019-01-04T23:33:00Z',
#   'severity': 'Slight',
#   'borough': 'Barnet',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 29,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'PoweredTwoWheeler',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Motorcycle_50_125cc'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 345981,
#   'lat': 51.512198,
#   'lon': -0.153122,
#   'location': "On north Audley Street Near The Junction With Lee's Place",
#   'date': '2019-01-04T22:15:00Z',
#   'severity': 'Slight',
#   'borough': 'City of Westminster',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 48,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 345982,
#   'lat': 51.43148,
#   'lon': -0.016083,
#   'location': 'On Bromley Road Near The Junction With Daneswood Avenue',
#   'date': '2019-01-04T18:00:00Z',
#   'severity': 'Slight',
#   'borough': 'Lewisham',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 23,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'PoweredTwoWheeler',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Motorcycle_50_125cc'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 345983,
#   'lat': 51.473487,
#   'lon': 0.145202,
#   'location': 'On Belmont Road Near The Junction With Bedonwell Road',
#   'date': '2019-01-04T20:45:00Z',
#   'severity': 'Slight',
#   'borough': 'Bexley',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 24,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 18,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 345984,
#   'lat': 51.624011,
#   'lon': -0.022909,
#   'location': 'On Waltham Way Near The Junction With Leadale Avenue',
#   'date': '2019-01-05T01:33:00Z',
#   'severity': 'Slight',
#   'borough': 'Waltham Forest',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 69,
#     'class': 'Passenger',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 345985,
#   'lat': 51.518173,
#   'lon': 0.056305,
#   'location': 'On Evelyn Denington Road Near The Junction With Harrier Road',
#   'date': '2019-01-05T02:03:00Z',
#   'severity': 'Serious',
#   'borough': 'Newham',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 38,
#     'class': 'Driver',
#     'severity': 'Serious',
#     'mode': 'PoweredTwoWheeler',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Motorcycle_50_125cc'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 345986,
#   'lat': 51.532833,
#   'lon': -0.274567,
#   'location': 'On Abbey Road Near The Junction With Whitby Avenue',
#   'date': '2019-01-05T06:00:00Z',
#   'severity': 'Slight',
#   'borough': 'Brent',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 42,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 345987,
#   'lat': 51.536252,
#   'lon': -0.391174,
#   'location': 'On White Hart Roundabout Near The Junction With White Hart Rounda',
#   'date': '2019-01-03T20:25:00Z',
#   'severity': 'Slight',
#   'borough': 'Ealing',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 35,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 345988,
#   'lat': 51.461446,
#   'lon': -0.298206,
#   'location': 'On Sheen Road Richmond Surrey Near The Junction With Church Roa',
#   'date': '2019-01-05T11:35:00Z',
#   'severity': 'Slight',
#   'borough': 'Richmond upon Thames',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 22,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'PedalCycle',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'PedalCycle'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Taxi'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 345989,
#   'lat': 51.478457,
#   'lon': -0.144534,
#   'location': 'On Battersea Park Road 46 metres west of The Junction With Prince',
#   'date': '2019-01-05T13:42:00Z',
#   'severity': 'Slight',
#   'borough': 'Wandsworth',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 76,
#     'class': 'Pedestrian',
#     'severity': 'Slight',
#     'mode': 'Pedestrian',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 345990,
#   'lat': 51.478749,
#   'lon': -0.407771,
#   'location': 'On Bath Road 28 metres west of The Junction With Clevedon Gardens',
#   'date': '2019-01-05T12:40:00Z',
#   'severity': 'Slight',
#   'borough': 'Hounslow',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 44,
#     'class': 'Pedestrian',
#     'severity': 'Slight',
#     'mode': 'Pedestrian',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Taxi'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 345991,
#   'lat': 51.428715,
#   'lon': -0.323935,
#   'location': 'On Kingston Road 10 metres south of The Junction With Ferry Road',
#   'date': '2019-01-05T15:02:00Z',
#   'severity': 'Slight',
#   'borough': 'Richmond upon Thames',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 24,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'PedalCycle',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'PedalCycle'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 345992,
#   'lat': 51.514643,
#   'lon': -0.008552,
#   'location': 'On Blackwall Tunnel northern Approach Near The Junction With Andr',
#   'date': '2019-01-05T13:10:00Z',
#   'severity': 'Slight',
#   'borough': 'Tower Hamlets',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 26,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 345993,
#   'lat': 51.490922,
#   'lon': -0.228945,
#   'location': 'Bridge View Near The Junction With Bridge View',
#   'date': '2019-01-05T16:00:00Z',
#   'severity': 'Slight',
#   'borough': 'Hammersmith and Fulham',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 46,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'PedalCycle',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'PedalCycle'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 345994,
#   'lat': 51.598083,
#   'lon': -0.105601,
#   'location': 'On Lordship Lane 15 metres east of The Junction With Vincent Road',
#   'date': '2019-01-05T14:50:00Z',
#   'severity': 'Slight',
#   'borough': 'Haringey',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'class': 'Pedestrian',
#     'severity': 'Slight',
#     'mode': 'Pedestrian',
#     'ageBand': 'Unknown'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'class': 'Pedestrian',
#     'severity': 'Slight',
#     'mode': 'Pedestrian',
#     'ageBand': 'Unknown'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 345995,
#   'lat': 51.5238,
#   'lon': 0.057496,
#   'location': 'On High Street south Near The Junction With Melford Road E6',
#   'date': '2019-01-05T16:15:00Z',
#   'severity': 'Serious',
#   'borough': 'Newham',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 13,
#     'class': 'Pedestrian',
#     'severity': 'Serious',
#     'mode': 'Pedestrian',
#     'ageBand': 'Child'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 345996,
#   'lat': 51.401604,
#   'lon': -0.168364,
#   'location': 'On Lower Green west Near The Junction With London Road',
#   'date': '2019-01-05T13:50:00Z',
#   'severity': 'Slight',
#   'borough': 'Merton',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 32,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'class': 'Passenger',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Unknown'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'LightGoodsVehicle'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 345997,
#   'lat': 51.432204,
#   'lon': -0.178088,
#   'location': 'On Garratt Lane 25 metres north of The Junction With Smallwood Ro',
#   'date': '2019-01-05T17:37:00Z',
#   'severity': 'Serious',
#   'borough': 'Wandsworth',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 49,
#     'class': 'Driver',
#     'severity': 'Serious',
#     'mode': 'PedalCycle',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'PedalCycle'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 345998,
#   'lat': 51.57724,
#   'lon': -0.20644,
#   'location': 'On Golders Green Road Near The Junction With Limes Avenue',
#   'date': '2019-01-05T13:30:00Z',
#   'severity': 'Slight',
#   'borough': 'Barnet',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 63,
#     'class': 'Passenger',
#     'severity': 'Slight',
#     'mode': 'BusOrCoach',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'BusOrCoach'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 345999,
#   'lat': 51.514361,
#   'lon': -0.235199,
#   'location': 'On westway Near The Junction With Bloemfontein Road W12',
#   'date': '2019-01-05T18:07:00Z',
#   'severity': 'Slight',
#   'borough': 'Hammersmith and Fulham',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 44,
#     'class': 'Passenger',
#     'severity': 'Slight',
#     'mode': 'BusOrCoach',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'BusOrCoach'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346000,
#   'lat': 51.45976,
#   'lon': -0.128019,
#   'location': 'On Acre Lane Near The Junction With Hetherington Road',
#   'date': '2019-01-05T14:20:00Z',
#   'severity': 'Serious',
#   'borough': 'Lambeth',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 31,
#     'class': 'Driver',
#     'severity': 'Serious',
#     'mode': 'PoweredTwoWheeler',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Motorcycle_500cc_Plus'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346001,
#   'lat': 51.640577,
#   'lon': -0.062396,
#   'location': 'On Great Cambridge Road Near The Junction With Lee Road Enfield',
#   'date': '2019-01-05T18:00:00Z',
#   'severity': 'Slight',
#   'borough': 'Enfield',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 56,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346002,
#   'lat': 51.527033,
#   'lon': -0.059406,
#   'location': 'Wilmot Street 25 metres south Bethnal Green Road',
#   'date': '2019-01-03T15:40:00Z',
#   'severity': 'Slight',
#   'borough': 'Tower Hamlets',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 47,
#     'class': 'Pedestrian',
#     'severity': 'Slight',
#     'mode': 'Pedestrian',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346003,
#   'lat': 51.554954,
#   'lon': 0.066518,
#   'location': 'On Ilford Hill Near The Junction With north Circular Road',
#   'date': '2019-01-05T16:20:00Z',
#   'severity': 'Slight',
#   'borough': 'Redbridge',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 22,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346004,
#   'lat': 51.498892,
#   'lon': -0.054882,
#   'location': 'On Lower Road Near The Junction With Rotherhite Tunnel',
#   'date': '2019-01-05T19:15:00Z',
#   'severity': 'Slight',
#   'borough': 'Southwark',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 10,
#     'class': 'Passenger',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Child'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346005,
#   'lat': 51.532286,
#   'lon': -0.083002,
#   'location': 'On Buckland Road Near The Junction With Pittfield Street',
#   'date': '2019-01-05T19:25:00Z',
#   'severity': 'Serious',
#   'borough': 'Hackney',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 42,
#     'class': 'Driver',
#     'severity': 'Serious',
#     'mode': 'PedalCycle',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'PedalCycle'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346006,
#   'lat': 51.531143,
#   'lon': -0.202774,
#   'location': 'On Marban Road Near The Junction With Ashmore Road',
#   'date': '2019-01-05T17:36:00Z',
#   'severity': 'Slight',
#   'borough': 'City of Westminster',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 26,
#     'class': 'Pedestrian',
#     'severity': 'Slight',
#     'mode': 'Pedestrian',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Taxi'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346007,
#   'lat': 51.458976,
#   'lon': -0.11891,
#   'location': 'On Baytree Road 50 metres east of The Junction With Brixton Hill',
#   'date': '2019-01-01T16:00:00Z',
#   'severity': 'Slight',
#   'borough': 'Lambeth',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 19,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'PoweredTwoWheeler',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Motorcycle_50_125cc'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346008,
#   'lat': 51.584706,
#   'lon': -0.106952,
#   'location': 'On Wightman Road Near The Junction With Fairfax Road',
#   'date': '2019-01-05T21:00:00Z',
#   'severity': 'Slight',
#   'borough': 'Haringey',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 24,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'OtherVehicle',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'OtherMotorVehicle'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346009,
#   'lat': 51.531439,
#   'lon': 0.017888,
#   'location': 'On Plaistow Road Near The Junction With Upper Road E13',
#   'date': '2019-01-05T20:40:00Z',
#   'severity': 'Slight',
#   'borough': 'Newham',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 25,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'PoweredTwoWheeler',
#     'ageBand': 'Adult'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 28,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Motorcycle_125_500cc'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346010,
#   'lat': 51.407501,
#   'lon': -0.136897,
#   'location': 'On Stanford Way Near The Junction With Beckway Road',
#   'date': '2019-01-05T17:05:00Z',
#   'severity': 'Slight',
#   'borough': 'Merton',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 23,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 54,
#     'class': 'Passenger',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346011,
#   'lat': 51.429707,
#   'lon': -0.104015,
#   'location': 'Ernest Avenue junction with A215 Knights Hill',
#   'date': '2019-01-05T07:02:00Z',
#   'severity': 'Slight',
#   'borough': 'Lambeth',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 26,
#     'class': 'Pedestrian',
#     'severity': 'Slight',
#     'mode': 'Pedestrian',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346012,
#   'lat': 51.573781,
#   'lon': -0.120986,
#   'location': 'Crouch Hill junction with Mount View Road',
#   'date': '2019-01-05T19:50:00Z',
#   'severity': 'Slight',
#   'borough': 'Islington',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 43,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346013,
#   'lat': 51.454698,
#   'lon': 0.178478,
#   'location': 'On Iron Mill Lane 38 metres west of The Junction With Rectory Clo',
#   'date': '2019-01-05T22:25:00Z',
#   'severity': 'Serious',
#   'borough': 'Bexley',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 39,
#     'class': 'Driver',
#     'severity': 'Serious',
#     'mode': 'Car',
#     'ageBand': 'Adult'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 30,
#     'class': 'Driver',
#     'severity': 'Serious',
#     'mode': 'Car',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346014,
#   'lat': 51.453143,
#   'lon': -0.050307,
#   'location': 'On Brenchley Gardens Se23 50 metres west of The Junction With Kel',
#   'date': '2019-01-06T01:50:00Z',
#   'severity': 'Slight',
#   'borough': 'Southwark',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 24,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346015,
#   'lat': 51.370727,
#   'lon': -0.100274,
#   'location': 'On High Street Near The Junction With High Street',
#   'date': '2019-01-06T04:05:00Z',
#   'severity': 'Slight',
#   'borough': 'Croydon',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 21,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346016,
#   'lat': 51.469853,
#   'lon': -0.125431,
#   'location': "On Clapham Road Near The Junction With Jeffrey's Road",
#   'date': '2019-01-05T12:30:00Z',
#   'severity': 'Serious',
#   'borough': 'Lambeth',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 35,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 35,
#     'class': 'Driver',
#     'severity': 'Serious',
#     'mode': 'PoweredTwoWheeler',
#     'ageBand': 'Adult'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 32,
#     'class': 'Passenger',
#     'severity': 'Slight',
#     'mode': 'PoweredTwoWheeler',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Motorcycle_500cc_Plus'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346017,
#   'lat': 51.577884,
#   'lon': 0.070127,
#   'location': 'On Cranbrook Road Near The Junction With Shere Road',
#   'date': '2019-01-04T17:22:00Z',
#   'severity': 'Slight',
#   'borough': 'Redbridge',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 41,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'PedalCycle',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'PedalCycle'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346018,
#   'lat': 51.432872,
#   'lon': -0.128571,
#   'location': 'On Streatham High Road Near The Junction With Gracefield Gardens',
#   'date': '2019-01-06T11:05:00Z',
#   'severity': 'Slight',
#   'borough': 'Lambeth',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 16,
#     'class': 'Pedestrian',
#     'severity': 'Slight',
#     'mode': 'Pedestrian',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346019,
#   'lat': 51.479059,
#   'lon': -0.188736,
#   'location': 'On Rumbold Road 10 metres east of The Junction With Kings Road south west of',
#   'date': '2019-01-06T10:42:00Z',
#   'severity': 'Serious',
#   'borough': 'Hammersmith and Fulham',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 5,
#     'class': 'Pedestrian',
#     'severity': 'Serious',
#     'mode': 'Pedestrian',
#     'ageBand': 'Child'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346020,
#   'lat': 51.552237,
#   'lon': -0.301643,
#   'location': 'On High Road Near The Junction With Napier Road',
#   'date': '2019-01-06T11:10:00Z',
#   'severity': 'Slight',
#   'borough': 'Brent',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 90,
#     'class': 'Pedestrian',
#     'severity': 'Slight',
#     'mode': 'Pedestrian',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346021,
#   'lat': 51.521225,
#   'lon': 0.058187,
#   'location': 'On Lonsdale Avenue Near The Junction With High Street south',
#   'date': '2019-01-06T12:15:00Z',
#   'severity': 'Slight',
#   'borough': 'Newham',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 24,
#     'class': 'Pedestrian',
#     'severity': 'Slight',
#     'mode': 'Pedestrian',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346022,
#   'lat': 51.530456,
#   'lon': 0.144736,
#   'location': 'On Chequers Lane Near The Junction With Merrilands Cresecent',
#   'date': '2019-01-06T11:30:00Z',
#   'severity': 'Slight',
#   'borough': 'Barking and Dagenham',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 47,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346023,
#   'lat': 51.592273,
#   'lon': 0.181763,
#   'location': 'On eastern Avenue east Near The Junction With Pettits Lane',
#   'date': '2019-01-05T21:15:00Z',
#   'severity': 'Serious',
#   'borough': 'Havering',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 14,
#     'class': 'Passenger',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Child'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 8,
#     'class': 'Passenger',
#     'severity': 'Serious',
#     'mode': 'Car',
#     'ageBand': 'Child'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 27,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 46,
#     'class': 'Passenger',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346024,
#   'lat': 51.526271,
#   'lon': 0.07237,
#   'location': 'On north Circular Road 20 metres north of The Junction With Alfre',
#   'date': '2019-01-05T15:55:00Z',
#   'severity': 'Serious',
#   'borough': 'Newham',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 59,
#     'class': 'Passenger',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 51,
#     'class': 'Passenger',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 81,
#     'class': 'Passenger',
#     'severity': 'Serious',
#     'mode': 'Car',
#     'ageBand': 'Adult'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 62,
#     'class': 'Passenger',
#     'severity': 'Serious',
#     'mode': 'Car',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'HeavyGoodsVehicle'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346025,
#   'lat': 51.500811,
#   'lon': 0.002112,
#   'location': 'Millennium Way junction with Waterview Drive',
#   'date': '2019-01-04T16:45:00Z',
#   'severity': 'Serious',
#   'borough': 'Greenwich',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 0,
#     'class': 'Passenger',
#     'severity': 'Serious',
#     'mode': 'BusOrCoach',
#     'ageBand': 'Child'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'BusOrCoach'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346026,
#   'lat': 51.486011,
#   'lon': 0.098646,
#   'location': 'On Plumstead High Street Near The Junction With Purrett Road',
#   'date': '2019-01-06T12:40:00Z',
#   'severity': 'Slight',
#   'borough': 'Greenwich',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 28,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346027,
#   'lat': 51.516379,
#   'lon': -0.188813,
#   'location': 'Queensway 30 metres north east of east of The Junction With Bishops Rri',
#   'date': '2019-01-06T14:20:00Z',
#   'severity': 'Slight',
#   'borough': 'City of Westminster',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 34,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'PoweredTwoWheeler',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Motorcycle_0_50cc'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346028,
#   'lat': 51.481206,
#   'lon': -0.44958,
#   'location': 'On Bath Road Near The Junction With Nene Road Heathrow',
#   'date': '2019-01-06T15:52:00Z',
#   'severity': 'Serious',
#   'borough': 'Hillingdon',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 28,
#     'class': 'Driver',
#     'severity': 'Serious',
#     'mode': 'Car',
#     'ageBand': 'Adult'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 47,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346029,
#   'lat': 51.425797,
#   'lon': -0.138901,
#   'location': 'Mitcham Lane 83 metres east of Aldrington Road',
#   'date': '2019-01-06T14:10:00Z',
#   'severity': 'Slight',
#   'borough': 'Lambeth',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 55,
#     'class': 'Passenger',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'LightGoodsVehicle'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346030,
#   'lat': 51.613697,
#   'lon': -0.124306,
#   'location': 'On Bowes Road 300 metres east of The Junction With Wilmer Way T',
#   'date': '2019-01-06T18:00:00Z',
#   'severity': 'Slight',
#   'borough': 'Enfield',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 43,
#     'class': 'Passenger',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Taxi'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346031,
#   'lat': 51.449997,
#   'lon': 0.029565,
#   'location': 'On westhorne Avenue Near The Junction With Sidcup Road',
#   'date': '2019-01-06T16:37:00Z',
#   'severity': 'Slight',
#   'borough': 'Greenwich',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 43,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 42,
#     'class': 'Passenger',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346032,
#   'lat': 51.515459,
#   'lon': -0.142094,
#   'location': 'On Regent Street Near The Junction With Oxford Street',
#   'date': '2019-01-06T16:50:00Z',
#   'severity': 'Slight',
#   'borough': 'City of Westminster',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 3,
#     'class': 'Pedestrian',
#     'severity': 'Slight',
#     'mode': 'Pedestrian',
#     'ageBand': 'Child'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Motorcycle_0_50cc'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346033,
#   'lat': 51.384766,
#   'lon': -0.189573,
#   'location': 'On Saint Helier Avenue Near The Junction With Bishopsford Road',
#   'date': '2019-01-06T17:45:00Z',
#   'severity': 'Slight',
#   'borough': 'Sutton',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 38,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346034,
#   'lat': 51.633077,
#   'lon': -0.130053,
#   'location': 'On Chase Side Near The Junction With No Name',
#   'date': '2019-01-06T18:35:00Z',
#   'severity': 'Slight',
#   'borough': 'Enfield',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 34,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'PoweredTwoWheeler',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Motorcycle_50_125cc'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346035,
#   'lat': 51.475726,
#   'lon': -0.036456,
#   'location': 'New Cross Road 27 metres east Clifton Rise',
#   'date': '2019-01-06T18:04:00Z',
#   'severity': 'Slight',
#   'borough': 'Lewisham',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 37,
#     'class': 'Pedestrian',
#     'severity': 'Slight',
#     'mode': 'Pedestrian',
#     'ageBand': 'Adult'}],
# ...
#     'age': 31,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'PedalCycle',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'PedalCycle'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346223,
#   'lat': 51.45889,
#   'lon': -0.289434,
#   'location': "On Queen's Road Richmond Tw10 Near The Junction With Lower Grov",
#   'date': '2019-01-10T08:30:00Z',
#   'severity': 'Slight',
#   'borough': 'Richmond upon Thames',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 40,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'PoweredTwoWheeler',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Motorcycle_500cc_Plus'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346224,
#   'lat': 51.41211,
#   'lon': 0.074796,
#   'location': 'On Royal Parade Near The Junction With Church Row',
#   'date': '2019-01-10T11:50:00Z',
#   'severity': 'Slight',
#   'borough': 'Bromley',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 16,
#     'class': 'Pedestrian',
#     'severity': 'Slight',
#     'mode': 'Pedestrian',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Motorcycle_500cc_Plus'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346225,
#   'lat': 51.632561,
#   'lon': -0.128094,
#   'location': 'On Chase Side Near The Junction With High Street',
#   'date': '2019-01-04T14:00:00Z',
#   'severity': 'Slight',
#   'borough': 'Enfield',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 20,
#     'class': 'Pedestrian',
#     'severity': 'Slight',
#     'mode': 'Pedestrian',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'BusOrCoach'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346226,
#   'lat': 51.429866,
#   'lon': -0.104339,
#   'location': "On Knight's Hill Se27 Near The Junction With Ernest Avenue",
#   'date': '2019-01-02T10:17:00Z',
#   'severity': 'Slight',
#   'borough': 'Lambeth',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 51,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'Taxi',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Taxi'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'LightGoodsVehicle'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346227,
#   'lat': 51.487147,
#   'lon': -0.116541,
#   'location': 'On Vauxhall Street Near The Junction With Kennington Lane',
#   'date': '2019-01-02T11:30:00Z',
#   'severity': 'Slight',
#   'borough': 'Lambeth',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 48,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'PedalCycle',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'PedalCycle'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346228,
#   'lat': 51.575606,
#   'lon': -0.325291,
#   'location': 'On Watford Road 30 metres east of The Junction With northwick Par',
#   'date': '2019-01-10T07:25:00Z',
#   'severity': 'Serious',
#   'borough': 'Brent',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 38,
#     'class': 'Driver',
#     'severity': 'Serious',
#     'mode': 'PoweredTwoWheeler',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Motorcycle_500cc_Plus'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346229,
#   'lat': 51.521201,
#   'lon': -0.114761,
#   'location': 'On Theobalds Road Near The Junction With John Street',
#   'date': '2019-01-10T09:10:00Z',
#   'severity': 'Serious',
#   'borough': 'Camden',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 52,
#     'class': 'Driver',
#     'severity': 'Serious',
#     'mode': 'PedalCycle',
#     'ageBand': 'Adult'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 32,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'PedalCycle',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'PedalCycle'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'PedalCycle'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346230,
#   'lat': 51.603298,
#   'lon': 0.194307,
#   'location': 'On Lower Bedfords Road 19 metres east of The Junction With Ash Lane',
#   'date': '2019-01-10T12:30:00Z',
#   'severity': 'Slight',
#   'borough': 'Havering',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 47,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'LightGoodsVehicle'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346231,
#   'lat': 51.526501,
#   'lon': -0.02803,
#   'location': 'On Bow Road Near The Junction With Merchant Street',
#   'date': '2019-01-10T12:08:00Z',
#   'severity': 'Serious',
#   'borough': 'Tower Hamlets',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 20,
#     'class': 'Driver',
#     'severity': 'Serious',
#     'mode': 'GoodsVehicle',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'LightGoodsVehicle'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346232,
#   'lat': 51.436536,
#   'lon': -0.087042,
#   'location': 'On Alleyn Park Near The Junction With Gallery Road',
#   'date': '2019-01-09T18:00:00Z',
#   'severity': 'Slight',
#   'borough': 'Southwark',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 28,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 28,
#     'class': 'Passenger',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346233,
#   'lat': 51.396246,
#   'lon': -0.069316,
#   'location': 'On Portland Road Near The Junction With Werndere Road',
#   'date': '2019-01-10T08:20:00Z',
#   'severity': 'Serious',
#   'borough': 'Croydon',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 56,
#     'class': 'Pedestrian',
#     'severity': 'Serious',
#     'mode': 'Pedestrian',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346234,
#   'lat': 51.40946,
#   'lon': -0.05218,
#   'location': 'On Avenue Road Near The Junction With Chesham Road',
#   'date': '2019-01-10T07:50:00Z',
#   'severity': 'Slight',
#   'borough': 'Bromley',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 36,
#     'class': 'Pedestrian',
#     'severity': 'Slight',
#     'mode': 'Pedestrian',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346235,
#   'lat': 51.407539,
#   'lon': -0.025517,
#   'location': 'On Kelsey Park Road Near The Junction With Becknham High Street',
#   'date': '2019-01-10T08:05:00Z',
#   'severity': 'Slight',
#   'borough': 'Bromley',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 55,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 35,
#     'class': 'Pedestrian',
#     'severity': 'Slight',
#     'mode': 'Pedestrian',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346236,
#   'lat': 51.490695,
#   'lon': -0.284441,
#   'location': 'On Chiswick High Road 35 metres south of The Junction With Claren',
#   'date': '2019-01-10T14:45:00Z',
#   'severity': 'Slight',
#   'borough': 'Hounslow',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 30,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'GoodsVehicle',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'LightGoodsVehicle'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346237,
#   'lat': 51.588291,
#   'lon': -0.109574,
#   'location': 'On Wightman Road Near The Junction With Sydney Road',
#   'date': '2019-01-10T08:20:00Z',
#   'severity': 'Slight',
#   'borough': 'Haringey',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 29,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'PoweredTwoWheeler',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Motorcycle_50_125cc'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346238,
#   'lat': 51.486857,
#   'lon': -0.036338,
#   'location': 'On Evelyn Street Near The Junction With Grinstead Road',
#   'date': '2019-01-10T10:15:00Z',
#   'severity': 'Slight',
#   'borough': 'Lewisham',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 34,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'PedalCycle',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'PedalCycle'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'OtherMotorVehicle'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346239,
#   'lat': 51.557908,
#   'lon': -0.298893,
#   'location': 'On The Glen Near The Junction With Castleton Avenue',
#   'date': '2019-01-10T16:40:00Z',
#   'severity': 'Slight',
#   'borough': 'Brent',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 34,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346240,
#   'lat': 51.608936,
#   'lon': -0.365788,
#   'location': 'On Uxbridge Road Near The Junction With Milne Feild',
#   'date': '2019-01-10T16:45:00Z',
#   'severity': 'Slight',
#   'borough': 'Harrow',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 39,
#     'class': 'Pedestrian',
#     'severity': 'Slight',
#     'mode': 'Pedestrian',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'}]},
#  {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.AccidentDetail, Tfl.Api.Presentation.Entities',
#   'id': 346241,
#   'lat': 51.494515,
#   'lon': -0.438771,
#   'location': 'On M4 600 metres east of The Junction With Junction 4A The Near',
#   'date': '2019-01-10T16:10:00Z',
#   'severity': 'Slight',
#   'borough': 'Hillingdon',
#   'casualties': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Casualty, Tfl.Api.Presentation.Entities',
#     'age': 37,
#     'class': 'Driver',
#     'severity': 'Slight',
#     'mode': 'Car',
#     'ageBand': 'Adult'}],
#   'vehicles': [{'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'Car'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'LightGoodsVehicle'},
#    {'$type': 'Tfl.Api.Presentation.Entities.AccidentStats.Vehicle, Tfl.Api.Presentation.Entities',
#     'type': 'LightGoodsVehicle'}]},
#  ...]

# %% [markdown]
# 2. Via URL 'arguments', by specifying `key=value` argument pairs in the URL by appending them after a `?` and separating multiple `key=value` pairs using `&`. For example, below we use an API to retrieve US data specifying arguments. We use `drilldowns=Nation` to indicate the granularity at which we retrieve information. Try changing this argument value to `State`. Similarly, we use `measures=Population`. Check https://datausa.io/about/api/ for more details.

# %%
res = requests.get("https://datausa.io/api/data?drilldowns=Nation&measures=Population")
res_json = res.json()
res_json
# Out:
# {'data': [{'ID Nation': '01000US',
#    'Nation': 'United States',
#    'ID Year': 2022,
#    'Year': '2022',
#    'Population': 331097593,
#    'Slug Nation': 'united-states'},
#   {'ID Nation': '01000US',
#    'Nation': 'United States',
#    'ID Year': 2021,
#    'Year': '2021',
#    'Population': 329725481,
#    'Slug Nation': 'united-states'},
#   {'ID Nation': '01000US',
#    'Nation': 'United States',
#    'ID Year': 2020,
#    'Year': '2020',
#    'Population': 326569308,
#    'Slug Nation': 'united-states'},
#   {'ID Nation': '01000US',
#    'Nation': 'United States',
#    'ID Year': 2019,
#    'Year': '2019',
#    'Population': 324697795,
#    'Slug Nation': 'united-states'},
#   {'ID Nation': '01000US',
#    'Nation': 'United States',
#    'ID Year': 2018,
#    'Year': '2018',
#    'Population': 322903030,
#    'Slug Nation': 'united-states'},
#   {'ID Nation': '01000US',
#    'Nation': 'United States',
#    'ID Year': 2017,
#    'Year': '2017',
#    'Population': 321004407,
#    'Slug Nation': 'united-states'},
#   {'ID Nation': '01000US',
#    'Nation': 'United States',
#    'ID Year': 2016,
#    'Year': '2016',
#    'Population': 318558162,
#    'Slug Nation': 'united-states'},
#   {'ID Nation': '01000US',
#    'Nation': 'United States',
#    'ID Year': 2015,
#    'Year': '2015',
#    'Population': 316515021,
#    'Slug Nation': 'united-states'},
#   {'ID Nation': '01000US',
#    'Nation': 'United States',
#    'ID Year': 2014,
#    'Year': '2014',
#    'Population': 314107084,
#    'Slug Nation': 'united-states'},
#   {'ID Nation': '01000US',
#    'Nation': 'United States',
#    'ID Year': 2013,
#    'Year': '2013',
#    'Population': 311536594,
#    'Slug Nation': 'united-states'}],
#  'source': [{'measures': ['Population'],
#    'annotations': {'source_name': 'Census Bureau',
#     'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.',
#     'dataset_name': 'ACS 5-year Estimate',
#     'dataset_link': 'http://www.census.gov/programs-surveys/acs/',
#     'table_id': 'B01003',
#     'topic': 'Diversity',
#     'subtopic': 'Demographics'},
#    'name': 'acs_yg_total_population_5',
#    'substitutions': []}]}

# %% [markdown]
# URL arguments can be difficult to read due to the long verbose format, but at least the order of the additional arguments does not matter.

# %%
res = requests.get("https://datausa.io/api/data?measures=Population&drilldowns=Nation")
res_json2 = res.json()
res_json == res_json
# Out:
# True

# %% [markdown]
# As using arguments in URLs is such a common operation, there are helper functions in the package `requests` to simplify calling endpoints with arguments.

# %%
params = {
    "measures" : "Population",
    "drilldowns" : "Nation"
}
requests.get("https://datausa.io/api/data", params=params).json()
res_json3 = res.json()
res_json == res_json
# Out:
# True

# %% [markdown]
# ## Web scraping
#
# Sometimes we want to extract information from web pages that is not explicitly provided in a JSON API. In that case, we have to parse/process the HTML directly. This is called 'web scraping'. One is able to do so in an automated way, and when automating this the process is called 'web scraping'. For more info see the [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) python library, which has many efficient helper methods for parsing HTML to extract information of interest.
#
# When scraping information from web pages be considerate of the server you are requesting from, as it is designed for human interaction. Try to limit rate requests to avoid overloading the server, otherwise you might get blocked for a while.
